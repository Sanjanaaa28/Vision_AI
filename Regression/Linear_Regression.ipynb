# %%
# hours study      marks 
#  2                 40 
#  3                 50
#  4                 60

# %%
# Relationship btw hours and marks
# Independent var - var
# dependent var - marks

# %%
# y = mx+c
#y= predicted o/p
# X =  input 
# m = slope
# c = intercept

# %%
# EX - marks 
# marks = 10* 5 + 20= 70

# %%
import pandas as pd # data handling

# %%
import numpy as np # numerical calculations

# %%
import matplotlib.pyplot as plt # visual graphs plot

# %%
from sklearn.model_selection import train_test_split # random suffle, split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score # evalute

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

# %%
print(type(diabetes))  # similar to dictonary
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(diabetes.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
print(diabetes.feature_names) #col
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df = pd.DataFrame(
    diabetes.data,
    columns = diabetes.feature_names
)

# %%
df["target"] = diabetes.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0

# %%
print("Row:", df.shape[0])
# Out:
# Row: 442

# %%
print("columns: ", df.shape[1])
# Out:
# columns:  11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.268604e-17  1.130318e-17
# ...

# %%
df.describe().T
# Out:
#         count          mean        std        min        25%         50%  \
# age     442.0 -2.511817e-19   0.047619  -0.107226  -0.037299    0.005383
# sex     442.0  1.230790e-17   0.047619  -0.044642  -0.044642   -0.044642
# bmi     442.0 -2.245564e-16   0.047619  -0.090275  -0.034229   -0.007284
# bp      442.0 -4.797570e-17   0.047619  -0.112399  -0.036656   -0.005670
# s1      442.0 -1.381499e-17   0.047619  -0.126781  -0.034248   -0.004321
# s2      442.0  3.918434e-17   0.047619  -0.115613  -0.030358   -0.003819
# s3      442.0 -5.777179e-18   0.047619  -0.102307  -0.035117   -0.006584
# s4      442.0 -9.042540e-18   0.047619  -0.076395  -0.039493   -0.002592
# s5      442.0  9.268604e-17   0.047619  -0.126097  -0.033246   -0.001947
# s6      442.0  1.130318e-17   0.047619  -0.137767  -0.033179   -0.001078
# target  442.0  1.521335e+02  77.093005  25.000000  87.000000  140.500000
#
#                75%         max
# age       0.038076    0.110727
# ...

# %%
df.isnull().sum() # count of null value
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
df.duplicated().sum() #dupl
# Out:
# np.int64(0)

# %%
x = df[['bmi']]
y = df['target']

# %%
# note 
# double brakets x = df[["bmi"]]  not

# %%
plt.figure(figsize=(8,5))
plt.scatter(x,y,color= "blue")
plt.xlabel("BML")
plt.ylabel("Disease progression")
plt.title("BMI vs Disease")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,y, test_size = 0.2,
    random_state = 42
    
)

# %%
len(x_train)
# Out:
# 353

# %%
len(x_test)
# Out:
# 89

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
comparision = pd.DataFrame({
    "Actual": y_test.values, 
    "Predicted": y_pred
})
comparision.head(20)
# Out:
#     Actual   Predicted
# 0    219.0  145.806227
# 1     70.0  188.857390
# 2    202.0  147.958785
# 3    230.0  203.925298
# 4    111.0  131.814599
# 5     84.0  127.509482
# 6    242.0  322.315998
# 7    272.0  197.467623
# 8     94.0   61.856458
# 9     96.0  167.331809
# 10    94.0  118.899250
# 11   252.0   94.144831
# 12    99.0   90.915993
# 13   297.0  166.255530
# 14   135.0   96.297389
# 15    67.0  157.645297
# 16   295.0  223.298321
# 17   264.0  240.518787
# 18   170.0  180.247158
# 19   275.0  210.382972

# %%
mae = mean_absolute_error(y_test,y_pred) #

# %%
mse = mean_squared_error(y_test, y_pred)  # errors more then panalty high

# %%
r2 = r2_score(y_test, y_pred)  # accurate

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_train, y_train, color = "green", label = "Training_data")
plt.plot(x_train, model.predict(x_train), color = "red", label = "Regression line ", linewidth = 2)
plt.xlabel("BMI")
plt.ylabel("Disease Progression")
plt.title("Simple linear regression")
plt.legend()
plt.show()

# %%
new_b = [[0.04]]
prediction = model.predict(new_b)
print(prediction)
# Out:
# [191.94646178]
# c:\Users\Sanjana\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
## Hours   marks

# %% [markdown]
# # Hours    marks
# #  1         30
# #  2         40
# #  3         45
# #  4         55
# #  5         65
# #  6         72
# #  7         80
# #  8         88

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 

# Dataset
data = {
    "Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Marks": [30, 40, 45, 55, 65, 72, 80, 88]
}

df = pd.DataFrame(data)

# Input (X) and Output (y)
X = df[["Hours"]]
y = df["Marks"]

# Create and train model
model = LinearRegression()
model.fit(X, y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
plt.figure(figsize=(8,5))
plt.plot(X, model.predict(X), color='blue')
plt.xlabel("BML")
plt.ylabel("Disease progression")
plt.title("BMI vs Disease")
plt.show()

# %%
prediction = model.predict([[9]])
print("Predicted Marks for 9 hours:", prediction[0])
# Out:
# Predicted Marks for 9 hours: 96.71428571428572
# c:\Users\Sanjana\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
