# %%
import pandas as pd

# %%
#series 
pd.Series((1,2,2,3), name="Age")
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# Name: Age, dtype: int64

# %%
# dataframe 
# dict 
di={"Name":["anand","mango","pen","mobile"], 
    "Identity":["human","fruit","object","none"]}

df=pd.DataFrame(di)
df
# Out:
#      Name Identity
# 0   anand    human
# 1   mango    fruit
# 2     pen   object
# 3  mobile     none

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(2)
# Out:
#     Name Identity
# 0  anand    human
# 1  mango    fruit

# %%
df.tail(2)
# Out:
#      Name Identity
# 2     pen   object
# 3  mobile     none

# %%
df.sample(2)
# Out:
#     Name Identity
# 0  anand    human
# 2    pen   object

# %%
df.head()
# Out:
#      Name Identity
# 0   anand    human
# 1   mango    fruit
# 2     pen   object
# 3  mobile     none

# %%
df['Name']
# Out:
# 0     anand
# 1     mango
# 2       pen
# 3    mobile
# Name: Name, dtype: object

# %%
df[["Name", "Identity"]]
# Out:
#      Name Identity
# 0   anand    human
# 1   mango    fruit
# 2     pen   object
# 3  mobile     none

# %%
count=[1,10,3,2]
df.insert(0,"count",count)

# %%
df
# Out:
#    count    Name Identity
# 0      1   anand    human
# 1     10   mango    fruit
# 2      3     pen   object
# 3      2  mobile     none

# %%
colour = "skin", "orange", "blue","black"

# %%
df["colour"]=colour

# %%
df["id"]= [1,2,3,4]

# %%
df.sample()
# Out:
#    count Name Identity colour  id
# 2      3  pen   object   blue   3

# %%
# new df df2 id, weight
df2 = pd.DataFrame({
    'id': [1,2,3,4,5],
    "weight": [55,62,48,70, None]
})

print(df2)
# Out:
#    id  weight
# 0   1    55.0
# 1   2    62.0
# 2   3    48.0
# 3   4    70.0
# 4   5     NaN

# %%
# merge or join 
pd.merge(df,df2, how="outer",on="id")
# Out:
#    count    Name Identity  colour  id  weight
# 0    1.0   anand    human    skin   1    55.0
# 1   10.0   mango    fruit  orange   2    62.0
# 2    3.0     pen   object    blue   3    48.0
# 3    2.0  mobile     none   black   4    70.0
# 4    NaN     NaN      NaN     NaN   5     NaN

# %%
pd.merge(df,df2,how=)  # set
